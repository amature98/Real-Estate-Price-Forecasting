# %% [markdown]
# # REAL ESTATE PRICE FORECASTING
#
# ## BUSINESS UNDERSTANDING
#
# STAKEHOLDER:
#
# Real Estate consulting company
#
# TASK:
#
# Our client is a real Estate Consulting Company whose primary task is to offer advice to their clients who want to invest in real estate but do not know where to invest. It is the job of the company to give the best zip codes where the clients can make investments for a period of time and make an ROI. My task therefore is to create a model that identifies neighbourhoods that have average prices under the budget a client has and willgive them the highest Return On Investment (ROI) if they were to sell after a certain period. This prediction will be made

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('ggplot')

# %%
data = pd.read_csv('zillow_data.csv')
data.head(5)
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14723 entries, 0 to 14722
# Columns: 272 entries, RegionID to 2018-04
# dtypes: float64(219), int64(49), object(4)
# memory usage: 30.6+ MB

# %%
data.describe().T
# Out:
#               count           mean            std      min       25%  \
# RegionID    14723.0   81075.010052   31934.118525  58196.0   67174.5
# RegionName  14723.0   48222.348706   29359.325439   1001.0   22101.5
# SizeRank    14723.0    7362.000000    4250.308342      1.0    3681.5
# 1996-04     13684.0  118299.123063   86002.509608  11300.0   68800.0
# 1996-05     13684.0  118419.044139   86155.673905  11500.0   68900.0
# ...             ...            ...            ...      ...       ...
# 2017-12     14723.0  281095.320247  367045.388033  14300.0  129900.0
# 2018-01     14723.0  282657.060382  369572.741938  14100.0  130600.0
# 2018-02     14723.0  284368.688447  371773.905107  13900.0  131050.0
# 2018-03     14723.0  286511.376757  372461.234695  13800.0  131950.0
# 2018-04     14723.0  288039.944305  372054.396908  13800.0  132400.0
#
#                  50%       75%         max
# RegionID     78007.0   90920.5    753844.0
# RegionName   46106.0   75205.5     99901.0
# ...

# %%
def get_datetimes(df):
    """
    Takes a dataframe:
    returns only those column names that can be converted into datetime objects 
    as datetime objects.
    NOTE number of returned columns may not match total number of columns in passed dataframe
    """
    
    return pd.to_datetime(df.columns.values[7:], format='%Y-%m')

# %%
get_datetimes(data)
# Out:
# DatetimeIndex(['1996-04-01', '1996-05-01', '1996-06-01', '1996-07-01',
#                '1996-08-01', '1996-09-01', '1996-10-01', '1996-11-01',
#                '1996-12-01', '1997-01-01',
#                ...
#                '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01',
#                '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01',
#                '2018-03-01', '2018-04-01'],
#               dtype='datetime64[ns]', length=265, freq=None)
